# %% [markdown]
# Decision Tree and Random Forest Tree Project

# %%
#1-**Import the usual libraries for pandas and plotting. You can import sklearn later on.**

# %%
import pandas as pd   # Data Analysis Library
import numpy as np

# %%
import seaborn as sns  # Data Visualization Library
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#2-** Use pandas to read loan_data.csv as a dataframe called loans.**

# %%
import pandas as pd

# %%
url="https://raw.githubusercontent.com/shivanipriya89/DataScienceLoan/main/loan_data.csv"

# %%
df=pd.read_csv(url)

# %%
df # Original data frame. This is the data frame of loan_data
# Out:
#       credit.policy             purpose  int.rate  installment  \
# 0                 1  debt_consolidation    0.1189       829.10
# 1                 1         credit_card    0.1071       228.22
# 2                 1  debt_consolidation    0.1357       366.86
# 3                 1  debt_consolidation    0.1008       162.34
# 4                 1         credit_card    0.1426       102.92
# ...             ...                 ...       ...          ...
# 9573              0           all_other    0.1461       344.76
# 9574              0           all_other    0.1253       257.70
# 9575              0  debt_consolidation    0.1071        97.81
# 9576              0    home_improvement    0.1600       351.58
# 9577              0  debt_consolidation    0.1392       853.43
#
#       log.annual.inc    dti  fico  days.with.cr.line  revol.bal  revol.util  \
# 0          11.350407  19.48   737        5639.958333      28854        52.1
# ...

# %%
#3-** Check out the info(), head(), and describe() methods on loans.**

# %%
df.info() # Concise information of data frame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
df.head() # Top 5 rows of data frame
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# ...

# %%
df.describe() # Statistical analysis of data frame
# Out:
#        credit.policy     int.rate  installment  log.annual.inc          dti  \
# count    9578.000000  9578.000000  9578.000000     9578.000000  9578.000000
# mean        0.804970     0.122640   319.089413       10.932117    12.606679
# std         0.396245     0.026847   207.071301        0.614813     6.883970
# min         0.000000     0.060000    15.670000        7.547502     0.000000
# 25%         1.000000     0.103900   163.770000       10.558414     7.212500
# 50%         1.000000     0.122100   268.950000       10.928884    12.665000
# 75%         1.000000     0.140700   432.762500       11.291293    17.950000
# max         1.000000     0.216400   940.140000       14.528354    29.960000
#
#               fico  days.with.cr.line     revol.bal   revol.util  \
# count  9578.000000        9578.000000  9.578000e+03  9578.000000
# mean    710.846314        4560.767197  1.691396e+04    46.799236
# std      37.970537        2496.930377  3.375619e+04    29.014417
# ...

# %%
df.describe(include="all") # Statistical analysis of data frame including the null values
# Out:
#         credit.policy             purpose     int.rate  installment  \
# count     9578.000000                9578  9578.000000  9578.000000
# unique            NaN                   7          NaN          NaN
# top               NaN  debt_consolidation          NaN          NaN
# freq              NaN                3957          NaN          NaN
# mean         0.804970                 NaN     0.122640   319.089413
# std          0.396245                 NaN     0.026847   207.071301
# min          0.000000                 NaN     0.060000    15.670000
# 25%          1.000000                 NaN     0.103900   163.770000
# 50%          1.000000                 NaN     0.122100   268.950000
# 75%          1.000000                 NaN     0.140700   432.762500
# max          1.000000                 NaN     0.216400   940.140000
#
#         log.annual.inc          dti         fico  days.with.cr.line  \
# count      9578.000000  9578.000000  9578.000000        9578.000000
# ...

# %%
#4- Exploratory Data Analysis

# %%
#4-a)-Create a histogram of two FICO distributions on top of each other, one for each credit.policy outcome.**

# %%
df.columns
# Out:
# Index(['credit.policy', 'purpose', 'int.rate', 'installment', 'log.annual.inc',
#        'dti', 'fico', 'days.with.cr.line', 'revol.bal', 'revol.util',
#        'inq.last.6mths', 'delinq.2yrs', 'pub.rec', 'not.fully.paid'],
#       dtype='object')

# %%
plt.figure(figsize=(12,6))
df["fico"].plot(kind="hist",bins=50,cmap="flare") # Histogram of fico credit score of borrower
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df[df["credit.policy"]==1]["fico"].hist(bins=35,color="blue",label="credit policy==1")
df[df["credit.policy"]==0]["fico"].hist(bins=35,color="red",label="credit policy==0") # Histogram of fico column
plt.legend()

# %%
#4-b** Create a similar figure, except this time select by the not.fully.paid column.**

# %%
df.columns
# Out:
# Index(['credit.policy', 'purpose', 'int.rate', 'installment', 'log.annual.inc',
#        'dti', 'fico', 'days.with.cr.line', 'revol.bal', 'revol.util',
#        'inq.last.6mths', 'delinq.2yrs', 'pub.rec', 'not.fully.paid'],
#       dtype='object')

# %%
df["not.fully.paid"].value_counts()
# Out:
# 0    8045
# 1    1533
# Name: not.fully.paid, dtype: int64

# %%
df[df["not.fully.paid"]==0]["fico"].hist(bins=35,color="blue",label="fully paid==0",alpha=0.6)
df[df["not.fully.paid"]==1]["fico"].hist(bins=35,color="orange",label="fully paid==1",alpha=0.6)
# Out:
# <AxesSubplot:>

# %%
#5-Create a countplot using seaborn showing the counts of loans by purpose, with the color hue defined by not.fully.paid. **

# %%
df.columns # Columns of dataframe
# Out:
# Index(['credit.policy', 'purpose', 'int.rate', 'installment', 'log.annual.inc',
#        'dti', 'fico', 'days.with.cr.line', 'revol.bal', 'revol.util',
#        'inq.last.6mths', 'delinq.2yrs', 'pub.rec', 'not.fully.paid'],
#       dtype='object')

# %%
df["purpose"].value_counts() # Different category of loan types
# Out:
# debt_consolidation    3957
# all_other             2331
# credit_card           1262
# home_improvement       629
# small_business         619
# major_purchase         437
# educational            343
# Name: purpose, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot(df["purpose"],data=df,hue="not.fully.paid") # Countplot of loanpurpose column
# Out:
# /usr/local/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='purpose', ylabel='count'>

# %%
#6-** Let's see the trend between FICO score and interest rate. Recreate the following jointplot.**

# %%
import pandas as pd

# %%
url="https://raw.githubusercontent.com/shivanipriya89/DataScienceLoan/main/loan_data.csv"

# %%
df=pd.read_csv(url)

# %%
df # Original data frame
# Out:
#       credit.policy             purpose  int.rate  installment  \
# 0                 1  debt_consolidation    0.1189       829.10
# 1                 1         credit_card    0.1071       228.22
# 2                 1  debt_consolidation    0.1357       366.86
# 3                 1  debt_consolidation    0.1008       162.34
# 4                 1         credit_card    0.1426       102.92
# ...             ...                 ...       ...          ...
# 9573              0           all_other    0.1461       344.76
# 9574              0           all_other    0.1253       257.70
# 9575              0  debt_consolidation    0.1071        97.81
# 9576              0    home_improvement    0.1600       351.58
# 9577              0  debt_consolidation    0.1392       853.43
#
#       log.annual.inc    dti  fico  days.with.cr.line  revol.bal  revol.util  \
# 0          11.350407  19.48   737        5639.958333      28854        52.1
# ...

# %%
df.columns
# Out:
# Index(['credit.policy', 'purpose', 'int.rate', 'installment', 'log.annual.inc',
#        'dti', 'fico', 'days.with.cr.line', 'revol.bal', 'revol.util',
#        'inq.last.6mths', 'delinq.2yrs', 'pub.rec', 'not.fully.paid'],
#       dtype='object')

# %%
df[["fico","int.rate"]] # Clubing the fico and interest rate column
# Out:
#       fico  int.rate
# 0      737    0.1189
# 1      707    0.1071
# 2      682    0.1357
# 3      712    0.1008
# 4      667    0.1426
# ...    ...       ...
# 9573   672    0.1461
# 9574   722    0.1253
# 9575   687    0.1071
# 9576   692    0.1600
# 9577   732    0.1392
#
# [9578 rows x 2 columns]

# %%
x=df["fico"]

# %%
y=df["int.rate"]

# %%
import seaborn as sns

# %%
sns.jointplot(x,y,data=df,color="purple") # Jointplot between fico and interest rate
# Out:
# /usr/local/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#7-Create the following lmplots to see if the trend differed between not.fully.paid and credit.policy.

# %%
df.columns
# Out:
# Index(['credit.policy', 'purpose', 'int.rate', 'installment', 'log.annual.inc',
#        'dti', 'fico', 'days.with.cr.line', 'revol.bal', 'revol.util',
#        'inq.last.6mths', 'delinq.2yrs', 'pub.rec', 'not.fully.paid'],
#       dtype='object')

# %%
sns.lmplot(x="not.fully.paid",y="credit.policy",data=df)

# %%
sns.lmplot(x="fico",y="int.rate",data=df,hue="credit.policy",col="not.fully.paid",palette="Set1")

# %%
#8-**Check loans.info() again.**

# %%
df.info() # Concise information of loan data frame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
#9-Notice that the **purpose** column as categorical

#That means we need to transform them using dummy variables so sklearn will be able to understand them. Let's do this in one clean step using pd.get_dummies.

#Let's show you a way of dealing with these columns that can be expanded to multiple categorical features if necessary.

#Create a list of 1 element containing the string 'purpose'. Call this list cat_feats.**

# %%
df.columns
# Out:
# Index(['credit.policy', 'purpose', 'int.rate', 'installment', 'log.annual.inc',
#        'dti', 'fico', 'catfeats', 'days.with.cr.line', 'revol.bal',
#        'revol.util', 'inq.last.6mths', 'delinq.2yrs', 'pub.rec',
#        'not.fully.paid'],
#       dtype='object')

# %%
cat_feats=["purpose"]

# %%
#10-**Now use pd.get_dummies(loans,columns=cat_feats,drop_first=True) to create a fixed larger dataframe that has new feature columns with dummy variables. 
#Set this dataframe as final_data.**

# %%
loans=df

# %%
loans # The loan data frame
# Out:
#       credit.policy             purpose  int.rate  installment  \
# 0                 1  debt_consolidation    0.1189       829.10
# 1                 1         credit_card    0.1071       228.22
# 2                 1  debt_consolidation    0.1357       366.86
# 3                 1  debt_consolidation    0.1008       162.34
# 4                 1         credit_card    0.1426       102.92
# ...             ...                 ...       ...          ...
# 9573              0           all_other    0.1461       344.76
# 9574              0           all_other    0.1253       257.70
# 9575              0  debt_consolidation    0.1071        97.81
# 9576              0    home_improvement    0.1600       351.58
# 9577              0  debt_consolidation    0.1392       853.43
#
#       log.annual.inc    dti  fico  days.with.cr.line  revol.bal  revol.util  \
# 0          11.350407  19.48   737        5639.958333      28854        52.1
# ...

# %%
final_data=pd.get_dummies(loans,columns=cat_feats,drop_first=True)

# %%
final_data
# Out:
#       credit.policy  int.rate  installment  log.annual.inc    dti  fico  \
# 0                 1    0.1189       829.10       11.350407  19.48   737
# 1                 1    0.1071       228.22       11.082143  14.29   707
# 2                 1    0.1357       366.86       10.373491  11.63   682
# 3                 1    0.1008       162.34       11.350407   8.10   712
# 4                 1    0.1426       102.92       11.299732  14.97   667
# ...             ...       ...          ...             ...    ...   ...
# 9573              0    0.1461       344.76       12.180755  10.39   672
# 9574              0    0.1253       257.70       11.141862   0.21   722
# 9575              0    0.1071        97.81       10.596635  13.09   687
# 9576              0    0.1600       351.58       10.819778  19.18   692
# 9577              0    0.1392       853.43       11.264464  16.28   732
#
#       days.with.cr.line  revol.bal  revol.util  inq.last.6mths  delinq.2yrs  \
# ...

# %%
#11-Now its time to split our data into a training set and a testing set!

# Use sklearn to split your data into a training set and a testing set as we've done in the past.**

# %%
final_data
# Out:
#       credit.policy  int.rate  installment  log.annual.inc    dti  fico  \
# 0                 1    0.1189       829.10       11.350407  19.48   737
# 1                 1    0.1071       228.22       11.082143  14.29   707
# 2                 1    0.1357       366.86       10.373491  11.63   682
# 3                 1    0.1008       162.34       11.350407   8.10   712
# 4                 1    0.1426       102.92       11.299732  14.97   667
# ...             ...       ...          ...             ...    ...   ...
# 9573              0    0.1461       344.76       12.180755  10.39   672
# 9574              0    0.1253       257.70       11.141862   0.21   722
# 9575              0    0.1071        97.81       10.596635  13.09   687
# 9576              0    0.1600       351.58       10.819778  19.18   692
# 9577              0    0.1392       853.43       11.264464  16.28   732
#
#       days.with.cr.line  revol.bal  revol.util  inq.last.6mths  delinq.2yrs  \
# ...

# %%
import sklearn

# %%
from sklearn.model_selection import train_test_split

# %%
final_data
# Out:
#       credit.policy  int.rate  installment  log.annual.inc    dti  fico  \
# 0                 1    0.1189       829.10       11.350407  19.48   737
# 1                 1    0.1071       228.22       11.082143  14.29   707
# 2                 1    0.1357       366.86       10.373491  11.63   682
# 3                 1    0.1008       162.34       11.350407   8.10   712
# 4                 1    0.1426       102.92       11.299732  14.97   667
# ...             ...       ...          ...             ...    ...   ...
# 9573              0    0.1461       344.76       12.180755  10.39   672
# 9574              0    0.1253       257.70       11.141862   0.21   722
# 9575              0    0.1071        97.81       10.596635  13.09   687
# 9576              0    0.1600       351.58       10.819778  19.18   692
# 9577              0    0.1392       853.43       11.264464  16.28   732
#
#       days.with.cr.line  revol.bal  revol.util  inq.last.6mths  delinq.2yrs  \
# ...

# %%
final_data.columns
# Out:
# Index(['credit.policy', 'int.rate', 'installment', 'log.annual.inc', 'dti',
#        'fico', 'days.with.cr.line', 'revol.bal', 'revol.util',
#        'inq.last.6mths', 'delinq.2yrs', 'pub.rec', 'not.fully.paid',
#        'purpose_credit_card', 'purpose_debt_consolidation',
#        'purpose_educational', 'purpose_home_improvement',
#        'purpose_major_purchase', 'purpose_small_business'],
#       dtype='object')

# %%
x=final_data.drop("not.fully.paid",axis=1)

# %%
y=final_data["not.fully.paid"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=101)

# %%
x_train
# Out:
#       credit.policy  int.rate  installment  log.annual.inc    dti  fico  \
# 4845              1    0.1426       548.90       10.714418  14.67   682
# 6910              1    0.0774       312.19       10.819778   0.86   772
# 8146              0    0.1520       208.59       10.491274  18.53   642
# 7113              1    0.1385       511.56       10.950807  12.74   682
# 195               1    0.1059       130.18       11.034890  17.81   682
# ...             ...       ...          ...             ...    ...   ...
# 599               1    0.1671       710.18       11.082143  20.09   662
# 5695              1    0.1496       164.57       10.162770  22.36   662
# 8006              0    0.1659       531.74       10.616437  20.53   652
# 1361              1    0.0907       238.75       11.002100   4.86   752
# 1547              1    0.0800       142.59       10.978490   5.58   757
#
#       days.with.cr.line  revol.bal  revol.util  inq.last.6mths  delinq.2yrs  \
# ...

# %%
x_test
# Out:
#       credit.policy  int.rate  installment  log.annual.inc    dti  fico  \
# 5244              1    0.1287       274.12       10.933107  23.57   687
# 1739              1    0.1347       805.67       11.695247  24.50   712
# 2780              1    0.0768       124.77       10.545341  13.45   802
# 7062              1    0.1099       274.98       10.858999  18.62   702
# 6661              1    0.1913       550.81       11.736069   9.96   687
# ...             ...       ...          ...             ...    ...   ...
# 9508              0    0.1218       466.20       10.736310   5.32   727
# 4348              1    0.0894       111.21       10.239960   1.71   727
# 4233              1    0.1253       167.34        9.862666  12.06   687
# 5363              1    0.2017       447.01       11.225243  11.25   672
# 6599              1    0.1183       795.22       11.982929  12.63   812
#
#       days.with.cr.line  revol.bal  revol.util  inq.last.6mths  delinq.2yrs  \
# ...

# %%
y_train
# Out:
# 4845    1
# 6910    0
# 8146    1
# 7113    0
# 195     0
#        ..
# 599     0
# 5695    1
# 8006    0
# 1361    0
# 1547    0
# Name: not.fully.paid, Length: 6704, dtype: int64

# %%
y_test
# Out:
# 5244    0
# 1739    0
# 2780    0
# 7062    0
# 6661    0
#        ..
# 9508    0
# 4348    0
# 4233    0
# 5363    0
# 6599    0
# Name: not.fully.paid, Length: 2874, dtype: int64

# %%
#12-Start a Decision Tree Classifier

# %%
final_data
# Out:
#       credit.policy  int.rate  installment  log.annual.inc    dti  fico  \
# 0                 1    0.1189       829.10       11.350407  19.48   737
# 1                 1    0.1071       228.22       11.082143  14.29   707
# 2                 1    0.1357       366.86       10.373491  11.63   682
# 3                 1    0.1008       162.34       11.350407   8.10   712
# 4                 1    0.1426       102.92       11.299732  14.97   667
# ...             ...       ...          ...             ...    ...   ...
# 9573              0    0.1461       344.76       12.180755  10.39   672
# 9574              0    0.1253       257.70       11.141862   0.21   722
# 9575              0    0.1071        97.81       10.596635  13.09   687
# 9576              0    0.1600       351.58       10.819778  19.18   692
# 9577              0    0.1392       853.43       11.264464  16.28   732
#
#       days.with.cr.line  revol.bal  revol.util  inq.last.6mths  delinq.2yrs  \
# ...

# %%
import sklearn

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree=DecisionTreeClassifier()

# %%
#13-**Create an instance of DecisionTreeClassifier() called dtree and fit it to the training data.**

# %%
dtree=DecisionTreeClassifier()

# %%
dtree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
#14-Create predictions from the test set and create a classification report and a confusion matrix.**

# %%
predictions=dm.predict(x_test)

# %%
predictions
# Out:
# array([0, 1, 0, ..., 0, 0, 0])

# %%
import sklearn

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.81      0.83      2431
#            1       0.19      0.24      0.21       443
#
#     accuracy                           0.73      2874
#    macro avg       0.52      0.53      0.52      2874
# weighted avg       0.75      0.73      0.74      2874

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[1979  452]
#  [ 337  106]]

# %%
#15-**Create an instance of the RandomForestClassifier class and fit it to our 
#training data from the previous step.**

# %%
import sklearn

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc=RandomForestClassifier()

# %%
#16-Let's predict off the y_test values and evaluate our model.

# Predict the class of not.fully.paid for the X_test data.**

# %%
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=20)

# %%
rfc=RandomForestClassifier(n_estimators=20)

# %%
predictions=rfc.predict(x_test)

# %%
predictions
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
#17-Now create a classification report from the results. 
#Do you get anything strange or some sort of warning?**

# %%
import sklearn

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92      2431
#            1       0.44      0.02      0.03       443
#
#     accuracy                           0.85      2874
#    macro avg       0.65      0.51      0.48      2874
# weighted avg       0.79      0.85      0.78      2874

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[2421   10]
#  [ 435    8]]

# %%
#18- Which perform better random forest or the decision tree

# %% [markdown]
# By analyzing the classification report of Decision Tree and Random Forest,one can conclude that Decision Tree is better than random forest
